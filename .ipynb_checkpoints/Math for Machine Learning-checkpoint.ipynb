# %% [markdown]
# # Math for Machine Learning

# %% [markdown]
# ## 1. Linear Algebra

# %% [markdown]
# ### 1.1 Scalars, Vectors, Matrices and Tensors

# %%
from IPython.display import Image
Image('Images/m1.png', width=600)

# %%
Image('Images/vs.png', width=600)

# %% [markdown]
# Reference link: https://www.stephanosterburg.com/math_data_types
